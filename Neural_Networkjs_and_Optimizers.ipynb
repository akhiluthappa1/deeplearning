# %% [markdown]
# <a href="https://colab.research.google.com/github/akhiluthappa1/deeplearning/blob/main/Neural_Networkjs_and_Optimizers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## (1) Create a neural network with at least two hidden layers for a classification task. The dataset could be chosen arbitrarily, e.g. MNIST.
# ## (2) Experiment with three activation functions (one linear and one nonlinear) and report (i) accuracy and (ii) execution time

# %%
import time
import numpy as np
from tensorflow import keras
from tensorflow.keras.datasets import mnist

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the input data
x_train = x_train.reshape(-1, 784) / 255.0
x_test = x_test.reshape(-1, 784) / 255.0

# One-hot encode the target labels
y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

# Define the models with different activation functions
def linear_model():
    model = keras.Sequential([
        keras.layers.Dense(256, activation='linear', input_shape=(784,)),
        keras.layers.Dense(128, activation='linear'),
        keras.layers.Dense(128, activation='linear'),
        keras.layers.Dense(10, activation='softmax')
    ])
    return model

def relu_model():
    model = keras.Sequential([
        keras.layers.Dense(256, activation='relu', input_shape=(784,)),
        keras.layers.Dense(128, activation='relu'),
        keras.layers.Dense(128, activation='relu'),
        keras.layers.Dense(10, activation='softmax')
    ])
    return model

def sigmoid_model():
    model = keras.Sequential([
        keras.layers.Dense(256, activation='sigmoid', input_shape=(784,)),
        keras.layers.Dense(128, activation='sigmoid'),
        keras.layers.Dense(128, activation='sigmoid'),
        keras.layers.Dense(10, activation='softmax')
    ])
    return model

# Train and evaluate the models
models = [linear_model(), relu_model(), sigmoid_model()]

for model in models:
    start_time = time.time()
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    model.fit(x_train, y_train, batch_size=128, epochs=10, validation_data=(x_test, y_test))
    _, accuracy = model.evaluate(x_test, y_test)
    print(f'{model.layers[1].activation} model accuracy: {accuracy:.4f} | Execution time: {time.time()-start_time:.2f} sec')
# Out:
# Epoch 1/10
# 469/469 [==============================] - 6s 9ms/step - loss: 0.3814 - accuracy: 0.8884 - val_loss: 0.3128 - val_accuracy: 0.9102
# Epoch 2/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3140 - accuracy: 0.9114 - val_loss: 0.3398 - val_accuracy: 0.8960
# Epoch 3/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3048 - accuracy: 0.9133 - val_loss: 0.2946 - val_accuracy: 0.9173
# Epoch 4/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2963 - accuracy: 0.9161 - val_loss: 0.2863 - val_accuracy: 0.9190
# Epoch 5/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2904 - accuracy: 0.9191 - val_loss: 0.3114 - val_accuracy: 0.9150
# Epoch 6/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2879 - accuracy: 0.9189 - val_loss: 0.2928 - val_accuracy: 0.9157
# Epoch 7/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2836 - accuracy: 0.9197 - val_loss: 0.2983 - val_accuracy: 0.9162
# Epoch 8/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2806 - accuracy: 0.9207 - val_loss: 0.3042 - val_accuracy: 0.9151
# Epoch 9/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2775 - accuracy: 0.9225 - val_loss: 0.2857 - val_accuracy: 0.9225
# Epoch 10/10
# 469/469 [==============================] - 4s 7ms/step - loss: 0.2737 - accuracy: 0.9228 - val_loss: 0.3055 - val_accuracy: 0.9182
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3055 - accuracy: 0.9182
# <function linear at 0x7f083990ba60> model accuracy: 0.9182 | Execution time: 43.16 sec
# Epoch 1/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2732 - accuracy: 0.9223 - val_loss: 0.1243 - val_accuracy: 0.9631
# Epoch 2/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0995 - accuracy: 0.9695 - val_loss: 0.1194 - val_accuracy: 0.9634
# Epoch 3/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0681 - accuracy: 0.9787 - val_loss: 0.0881 - val_accuracy: 0.9733
# Epoch 4/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0492 - accuracy: 0.9852 - val_loss: 0.0778 - val_accuracy: 0.9760
# Epoch 5/10
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0399 - accuracy: 0.9864 - val_loss: 0.0785 - val_accuracy: 0.9742
# Epoch 6/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0304 - accuracy: 0.9898 - val_loss: 0.0715 - val_accuracy: 0.9801
# Epoch 7/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0220 - accuracy: 0.9928 - val_loss: 0.0915 - val_accuracy: 0.9762
# Epoch 8/10
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0210 - accuracy: 0.9929 - val_loss: 0.0800 - val_accuracy: 0.9788
# Epoch 9/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0178 - accuracy: 0.9940 - val_loss: 0.0912 - val_accuracy: 0.9765
# Epoch 10/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0189 - accuracy: 0.9937 - val_loss: 0.0846 - val_accuracy: 0.9783
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0846 - accuracy: 0.9783
# <function relu at 0x7f083990b040> model accuracy: 0.9783 | Execution time: 39.13 sec
# Epoch 1/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.7312 - accuracy: 0.7964 - val_loss: 0.2817 - val_accuracy: 0.9193
# Epoch 2/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2285 - accuracy: 0.9339 - val_loss: 0.1828 - val_accuracy: 0.9470
# Epoch 3/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1590 - accuracy: 0.9535 - val_loss: 0.1439 - val_accuracy: 0.9572
# Epoch 4/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1205 - accuracy: 0.9646 - val_loss: 0.1284 - val_accuracy: 0.9624
# Epoch 5/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0947 - accuracy: 0.9718 - val_loss: 0.1067 - val_accuracy: 0.9678
# Epoch 6/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0761 - accuracy: 0.9773 - val_loss: 0.0905 - val_accuracy: 0.9721
# Epoch 7/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0625 - accuracy: 0.9813 - val_loss: 0.0861 - val_accuracy: 0.9744
# Epoch 8/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0518 - accuracy: 0.9842 - val_loss: 0.0817 - val_accuracy: 0.9751
# Epoch 9/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0421 - accuracy: 0.9873 - val_loss: 0.0786 - val_accuracy: 0.9762
# Epoch 10/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0349 - accuracy: 0.9900 - val_loss: 0.0847 - val_accuracy: 0.9747
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0847 - accuracy: 0.9747
# <function sigmoid at 0x7f083990b550> model accuracy: 0.9747 | Execution time: 43.15 sec

# %% [markdown]
# ## (3) Experiment with three optimizers and report (i) accuracy and (ii) execution time.

# %%
import time
import numpy as np
from tensorflow import keras
from tensorflow.keras.datasets import mnist

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the input data
x_train = x_train.reshape(-1, 784) / 255.0
x_test = x_test.reshape(-1, 784) / 255.0

# One-hot encode the target labels
y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

# Define the models with different activation functions
def linear_model():
    model = keras.Sequential([
        keras.layers.Dense(256, activation='linear', input_shape=(784,)),
        keras.layers.Dense(128, activation='linear'),
        keras.layers.Dense(128, activation='linear'),
        keras.layers.Dense(10, activation='softmax')
    ])
    return model

def relu_model():
    model = keras.Sequential([
        keras.layers.Dense(256, activation='relu', input_shape=(784,)),
        keras.layers.Dense(128, activation='relu'),
        keras.layers.Dense(128, activation='relu'),
        keras.layers.Dense(10, activation='softmax')
    ])
    return model

def sigmoid_model():
    model = keras.Sequential([
        keras.layers.Dense(256, activation='sigmoid', input_shape=(784,)),
        keras.layers.Dense(128, activation='sigmoid'),
        keras.layers.Dense(128, activation='sigmoid'),
        keras.layers.Dense(10, activation='softmax')
    ])
    return model

# Train and evaluate the models
models = [linear_model(), relu_model(), sigmoid_model()]

optimizers = ['adam', 'sgd', 'rmsprop']

for optimizer in optimizers:
    for model in models:
        start_time = time.time()
        model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
        model.fit(x_train, y_train, batch_size=128, epochs=10, validation_data=(x_test, y_test))
        _, accuracy = model.evaluate(x_test, y_test)
        print(f'{model.layers[1].activation} model with {optimizer} optimizer accuracy: {accuracy:.4f} | Execution time: {time.time()-start_time:.2f} sec')
# Out:
# Epoch 1/10
# 469/469 [==============================] - 5s 8ms/step - loss: 0.3784 - accuracy: 0.8895 - val_loss: 0.3425 - val_accuracy: 0.9012
# Epoch 2/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3161 - accuracy: 0.9109 - val_loss: 0.2932 - val_accuracy: 0.9146
# Epoch 3/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3046 - accuracy: 0.9144 - val_loss: 0.3028 - val_accuracy: 0.9145
# Epoch 4/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2998 - accuracy: 0.9151 - val_loss: 0.3069 - val_accuracy: 0.9147
# Epoch 5/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2923 - accuracy: 0.9175 - val_loss: 0.3046 - val_accuracy: 0.9156
# Epoch 6/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2861 - accuracy: 0.9190 - val_loss: 0.2884 - val_accuracy: 0.9207
# Epoch 7/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2815 - accuracy: 0.9206 - val_loss: 0.2928 - val_accuracy: 0.9185
# Epoch 8/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2785 - accuracy: 0.9220 - val_loss: 0.3037 - val_accuracy: 0.9121
# Epoch 9/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2787 - accuracy: 0.9205 - val_loss: 0.3057 - val_accuracy: 0.9166
# Epoch 10/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2774 - accuracy: 0.9211 - val_loss: 0.2965 - val_accuracy: 0.9185
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2965 - accuracy: 0.9185
# <function linear at 0x7f083990ba60> model with adam optimizer accuracy: 0.9185 | Execution time: 42.51 sec
# Epoch 1/10
# 469/469 [==============================] - 5s 8ms/step - loss: 0.2688 - accuracy: 0.9208 - val_loss: 0.1334 - val_accuracy: 0.9599
# Epoch 2/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1001 - accuracy: 0.9702 - val_loss: 0.0898 - val_accuracy: 0.9710
# Epoch 3/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0673 - accuracy: 0.9791 - val_loss: 0.0847 - val_accuracy: 0.9751
# Epoch 4/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0481 - accuracy: 0.9843 - val_loss: 0.0811 - val_accuracy: 0.9756
# Epoch 5/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0370 - accuracy: 0.9887 - val_loss: 0.0728 - val_accuracy: 0.9780
# Epoch 6/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0289 - accuracy: 0.9909 - val_loss: 0.0839 - val_accuracy: 0.9761
# Epoch 7/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0271 - accuracy: 0.9911 - val_loss: 0.0807 - val_accuracy: 0.9763
# Epoch 8/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0219 - accuracy: 0.9927 - val_loss: 0.0768 - val_accuracy: 0.9788
# Epoch 9/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0183 - accuracy: 0.9941 - val_loss: 0.0894 - val_accuracy: 0.9793
# Epoch 10/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0141 - accuracy: 0.9953 - val_loss: 0.0886 - val_accuracy: 0.9790
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0886 - accuracy: 0.9790
# <function relu at 0x7f083990b040> model with adam optimizer accuracy: 0.9790 | Execution time: 42.51 sec
# Epoch 1/10
# 469/469 [==============================] - 5s 9ms/step - loss: 0.7209 - accuracy: 0.8025 - val_loss: 0.2606 - val_accuracy: 0.9252
# Epoch 2/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2231 - accuracy: 0.9352 - val_loss: 0.1842 - val_accuracy: 0.9442
# Epoch 3/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1572 - accuracy: 0.9530 - val_loss: 0.1432 - val_accuracy: 0.9552
# Epoch 4/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1223 - accuracy: 0.9636 - val_loss: 0.1194 - val_accuracy: 0.9625
# Epoch 5/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0975 - accuracy: 0.9722 - val_loss: 0.1063 - val_accuracy: 0.9666
# Epoch 6/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0795 - accuracy: 0.9768 - val_loss: 0.0906 - val_accuracy: 0.9715
# Epoch 7/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0653 - accuracy: 0.9803 - val_loss: 0.0912 - val_accuracy: 0.9714
# Epoch 8/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0547 - accuracy: 0.9839 - val_loss: 0.0797 - val_accuracy: 0.9758
# Epoch 9/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0461 - accuracy: 0.9865 - val_loss: 0.0784 - val_accuracy: 0.9758
# Epoch 10/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0383 - accuracy: 0.9883 - val_loss: 0.0785 - val_accuracy: 0.9771
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0785 - accuracy: 0.9771
# <function sigmoid at 0x7f083990b550> model with adam optimizer accuracy: 0.9771 | Execution time: 39.00 sec
# Epoch 1/10
# 469/469 [==============================] - 4s 7ms/step - loss: 0.2424 - accuracy: 0.9340 - val_loss: 0.2663 - val_accuracy: 0.9263
# Epoch 2/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2371 - accuracy: 0.9352 - val_loss: 0.2673 - val_accuracy: 0.9263
# Epoch 3/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2358 - accuracy: 0.9353 - val_loss: 0.2666 - val_accuracy: 0.9274
# Epoch 4/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2350 - accuracy: 0.9355 - val_loss: 0.2663 - val_accuracy: 0.9269
# Epoch 5/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2344 - accuracy: 0.9358 - val_loss: 0.2659 - val_accuracy: 0.9282
# Epoch 6/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2340 - accuracy: 0.9359 - val_loss: 0.2665 - val_accuracy: 0.9279
# Epoch 7/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2336 - accuracy: 0.9358 - val_loss: 0.2669 - val_accuracy: 0.9277
# Epoch 8/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2332 - accuracy: 0.9362 - val_loss: 0.2675 - val_accuracy: 0.9275
# Epoch 9/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2330 - accuracy: 0.9359 - val_loss: 0.2674 - val_accuracy: 0.9271
# Epoch 10/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2327 - accuracy: 0.9357 - val_loss: 0.2673 - val_accuracy: 0.9274
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2673 - accuracy: 0.9274
# <function linear at 0x7f083990ba60> model with sgd optimizer accuracy: 0.9274 | Execution time: 42.34 sec
# Epoch 1/10
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0064 - accuracy: 0.9983 - val_loss: 0.0792 - val_accuracy: 0.9812
# Epoch 2/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0044 - accuracy: 0.9991 - val_loss: 0.0772 - val_accuracy: 0.9815
# Epoch 3/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0036 - accuracy: 0.9993 - val_loss: 0.0762 - val_accuracy: 0.9815
# Epoch 4/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0032 - accuracy: 0.9995 - val_loss: 0.0755 - val_accuracy: 0.9818
# Epoch 5/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0028 - accuracy: 0.9996 - val_loss: 0.0751 - val_accuracy: 0.9819
# Epoch 6/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0026 - accuracy: 0.9996 - val_loss: 0.0748 - val_accuracy: 0.9821
# Epoch 7/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0024 - accuracy: 0.9996 - val_loss: 0.0748 - val_accuracy: 0.9819
# Epoch 8/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.0746 - val_accuracy: 0.9820
# Epoch 9/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0746 - val_accuracy: 0.9820
# Epoch 10/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.0747 - val_accuracy: 0.9820
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0747 - accuracy: 0.9820
# <function relu at 0x7f083990b040> model with sgd optimizer accuracy: 0.9820 | Execution time: 42.89 sec
# Epoch 1/10
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0268 - accuracy: 0.9930 - val_loss: 0.0744 - val_accuracy: 0.9781
# Epoch 2/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0250 - accuracy: 0.9938 - val_loss: 0.0738 - val_accuracy: 0.9778
# Epoch 3/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0244 - accuracy: 0.9939 - val_loss: 0.0734 - val_accuracy: 0.9780
# Epoch 4/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0241 - accuracy: 0.9941 - val_loss: 0.0730 - val_accuracy: 0.9781
# Epoch 5/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0238 - accuracy: 0.9942 - val_loss: 0.0728 - val_accuracy: 0.9781
# Epoch 6/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0235 - accuracy: 0.9944 - val_loss: 0.0724 - val_accuracy: 0.9780
# Epoch 7/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0233 - accuracy: 0.9944 - val_loss: 0.0722 - val_accuracy: 0.9781
# Epoch 8/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0231 - accuracy: 0.9945 - val_loss: 0.0720 - val_accuracy: 0.9783
# Epoch 9/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0229 - accuracy: 0.9945 - val_loss: 0.0718 - val_accuracy: 0.9784
# Epoch 10/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0228 - accuracy: 0.9947 - val_loss: 0.0717 - val_accuracy: 0.9783
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0717 - accuracy: 0.9783
# <function sigmoid at 0x7f083990b550> model with sgd optimizer accuracy: 0.9783 | Execution time: 33.47 sec
# Epoch 1/10
# 469/469 [==============================] - 5s 9ms/step - loss: 0.2802 - accuracy: 0.9204 - val_loss: 0.3286 - val_accuracy: 0.9071
# Epoch 2/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2775 - accuracy: 0.9222 - val_loss: 0.2817 - val_accuracy: 0.9221
# Epoch 3/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2745 - accuracy: 0.9224 - val_loss: 0.3073 - val_accuracy: 0.9133
# Epoch 4/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2730 - accuracy: 0.9227 - val_loss: 0.2924 - val_accuracy: 0.9201
# Epoch 5/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2698 - accuracy: 0.9241 - val_loss: 0.2915 - val_accuracy: 0.9184
# Epoch 6/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.2682 - accuracy: 0.9251 - val_loss: 0.3020 - val_accuracy: 0.9165
# Epoch 7/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2671 - accuracy: 0.9255 - val_loss: 0.2835 - val_accuracy: 0.9214
# Epoch 8/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2673 - accuracy: 0.9248 - val_loss: 0.2846 - val_accuracy: 0.9201
# Epoch 9/10
# 469/469 [==============================] - 3s 7ms/step - loss: 0.2651 - accuracy: 0.9253 - val_loss: 0.2827 - val_accuracy: 0.9215
# Epoch 10/10
# 469/469 [==============================] - 4s 7ms/step - loss: 0.2646 - accuracy: 0.9259 - val_loss: 0.2910 - val_accuracy: 0.9225
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2910 - accuracy: 0.9225
# <function linear at 0x7f083990ba60> model with rmsprop optimizer accuracy: 0.9225 | Execution time: 42.33 sec
# Epoch 1/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.0907 - val_accuracy: 0.9813
# Epoch 2/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0075 - accuracy: 0.9973 - val_loss: 0.1023 - val_accuracy: 0.9808
# Epoch 3/10
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0058 - accuracy: 0.9981 - val_loss: 0.0931 - val_accuracy: 0.9834
# Epoch 4/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0047 - accuracy: 0.9983 - val_loss: 0.1138 - val_accuracy: 0.9808
# Epoch 5/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.1184 - val_accuracy: 0.9806
# Epoch 6/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.1131 - val_accuracy: 0.9811
# Epoch 7/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.1327 - val_accuracy: 0.9815
# Epoch 8/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0035 - accuracy: 0.9988 - val_loss: 0.1323 - val_accuracy: 0.9798
# Epoch 9/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.1433 - val_accuracy: 0.9796
# Epoch 10/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0023 - accuracy: 0.9991 - val_loss: 0.1395 - val_accuracy: 0.9813
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1395 - accuracy: 0.9813
# <function relu at 0x7f083990b040> model with rmsprop optimizer accuracy: 0.9813 | Execution time: 40.07 sec
# Epoch 1/10
# 469/469 [==============================] - 5s 9ms/step - loss: 0.0293 - accuracy: 0.9915 - val_loss: 0.0900 - val_accuracy: 0.9725
# Epoch 2/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0249 - accuracy: 0.9927 - val_loss: 0.0760 - val_accuracy: 0.9788
# Epoch 3/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0225 - accuracy: 0.9933 - val_loss: 0.0741 - val_accuracy: 0.9791
# Epoch 4/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0196 - accuracy: 0.9945 - val_loss: 0.0770 - val_accuracy: 0.9803
# Epoch 5/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0172 - accuracy: 0.9953 - val_loss: 0.0747 - val_accuracy: 0.9793
# Epoch 6/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0152 - accuracy: 0.9956 - val_loss: 0.0812 - val_accuracy: 0.9787
# Epoch 7/10
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0131 - accuracy: 0.9963 - val_loss: 0.0933 - val_accuracy: 0.9750
# Epoch 8/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0123 - accuracy: 0.9964 - val_loss: 0.0814 - val_accuracy: 0.9793
# Epoch 9/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0101 - accuracy: 0.9972 - val_loss: 0.0810 - val_accuracy: 0.9795
# Epoch 10/10
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0087 - accuracy: 0.9976 - val_loss: 0.0828 - val_accuracy: 0.9803
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0828 - accuracy: 0.9803
# <function sigmoid at 0x7f083990b550> model with rmsprop optimizer accuracy: 0.9803 | Execution time: 39.68 sec

# %% [markdown]
# (4) Experiment with “Dropout layer”, “BatchNorm” and “Weight
# initialization” and report changes in accuracy and execution time

# %%
import time
import numpy as np
from tensorflow import keras
from tensorflow.keras.datasets import mnist

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the input data
x_train = x_train.reshape(-1, 784) / 255.0
x_test = x_test.reshape(-1, 784) / 255.0

# One-hot encode the target labels
y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

# Define the models with different activation functions
def dropout_model():
    model = keras.Sequential([
        keras.layers.Dense(256, activation='relu', input_shape=(784,)),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(128, activation='relu'),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(128, activation='relu'),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(10, activation='softmax')
    ])
    return model

def batchnorm_model():
    model = keras.Sequential([
        keras.layers.Dense(256, activation='relu', input_shape=(784,)),
        keras.layers.BatchNormalization(),
        keras.layers.Dense(128, activation='relu'),
        keras.layers.BatchNormalization(),
        keras.layers.Dense(128, activation='relu'),
        keras.layers.BatchNormalization(),
        keras.layers.Dense(10, activation='softmax')
    ])
    return model

def weightinit_model():
    model = keras.Sequential([
        keras.layers.Dense(256, activation='relu', kernel_initializer='he_uniform', input_shape=(784,)),
        keras.layers.Dense(128, activation='relu', kernel_initializer='he_uniform'),
        keras.layers.Dense(128, activation='relu', kernel_initializer='he_uniform'),
        keras.layers.Dense(10, activation='softmax', kernel_initializer='glorot_uniform')
    ])
    return model

# Train and evaluate the models
# models = [dropout_model(), batchnorm_model(), weightinit_model()]
models = [(dropout_model(), 'dropout_model'), (batchnorm_model(), 'batchnorm_model'), (weightinit_model(), 'weightinit_model')]

for model, model_name in models:
    print(f'Training {type(model).__name__}...')
    # for optimizer in ['adam', 'sgd', 'rmsprop']:
    start_time = time.time()
    model.compile(loss='categorical_crossentropy', metrics=['accuracy'])
    model.fit(x_train, y_train, batch_size=128, epochs=10, validation_data=(x_test, y_test), verbose=0)
    _, accuracy = model.evaluate(x_test, y_test, verbose=0)
    print(f'{model_name} model accuracy: {accuracy:.4f} | Execution time: {time.time()-start_time:.2f} sec')
    print('\n')
# Out:
# Training Sequential...
# dropout_model model accuracy: 0.9746 | Execution time: 42.36 sec
#
#
# Training Sequential...
# batchnorm_model model accuracy: 0.9800 | Execution time: 43.80 sec
#
#
# Training Sequential...
# weightinit_model model accuracy: 0.9792 | Execution time: 32.43 sec
